# %% [markdown]
# <a href="https://colab.research.google.com/github/aadhithyamohandas/thinkpalm-agentai-AadhithyaMohandas--ReAct-Agent/blob/main/Aadhithya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import ai

response = ai.generate_text("What is the weather in Kochi, kerala?")
print(response)
# Out:
# The weather in Kochi, Kerala is currently **29°C (84°F)** and it feels like 34°C (93°F) due to high humidity. The sky is **partly cloudy**.
#
# Humidity is around **80%**, and there's a light breeze.
#
# There's a chance of isolated showers later in the day.

# %%
import datetime

def get_current_time():
    return str(datetime.datetime.now())
def celsius_to_fahrenheit(c):
    return str((float(c) * 9/5) + 32)
def count_words(text):
    return str(len(text.split()))

# %%
def agent(query):
    print("User:", query)

    if any(x in query for x in ["+", "-", "*", "/"]):
        print("Thought: This is math")
        result = calculator(query)
        print("Final Answer:", result)

    elif "time" in query.lower():
        print("Thought: Need current time")
        result = get_current_time()
        print("Final Answer:", result)

    elif "convert" in query.lower():
        print("Thought: Need conversion")
        result = celsius_to_fahrenheit(30)
        print("Final Answer:", result)

# %%
agent("Convert 30 Celsius to Fahrenheit")
agent("What is the time?")
# Out:
# User: Convert 30 Celsius to Fahrenheit
# Thought: Need conversion
# Final Answer: 86.0
# User: What is the time?
# Thought: Need current time
# Final Answer: 2026-03-31 06:53:31.411214

# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyB6JAJ97f6KNIMJ66YiDMH8_YrHx7efhAo"

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

# Set your Gemini API key
genai.configure(api_key="AIzaSyB6JAJ97f6KNIMJ66YiDMH8_YrHx7efhAo")

model = genai.GenerativeModel("gemini-2.5-flash")

# %%
def get_weather(city):
    return f"The weather in {city} is asdasdasdsd 32°C, partly cloudy with high humidity."

# %%
import re

def react_agent(user_query):

    prompt = f"""
You are a ReAct agent. Follow this exact format:

Question: {user_query}

Thought: think step by step
Action: choose one tool [weather]
Action Input: input for the tool
Observation: result of the tool
Final Answer: final response to user

Available tools:
- weather(city)

Start now.
"""

    response = model.generate_content(prompt)
    output = response.text

    print("🧠 LLM Output:\n", output)
    if "Action: weather" in output:
        match = re.search(r"Action Input:\s*(.*)", output)

        if match:
            city = match.group(1).strip()

            # Call tool
            #observation = get_weather(city)
            final_prompt = f"""
{output}

Observation: {output}

Now give Final Answer.
"""

            final_response = model.generate_content(final_prompt)
            final_output = final_response.text

            print("\n✅ Final Answer:\n", final_output)

# %%
react_agent("What is the weather in Londan?")
# Out:
# 🧠 LLM Output:
#  Action: weather
# Action Input: London
# Observation: The weather in London is cloudy with a temperature of 10°C.
# Final Answer: The weather in London is cloudy with a temperature of 10°C.
#
# ✅ Final Answer:
#  Final Answer: The weather in London is cloudy with a temperature of 10°C.
